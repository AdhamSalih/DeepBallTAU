# %% [markdown]
# <a href="https://colab.research.google.com/github/AdhamSalih/DeepBallTAU/blob/master/ProjectDeepforBallDet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Project - Training Deep Network for ball detection with pytorch**
# This Project includes two models for Ball Detection - Regular data
# 1. DeepBall
# 2. DeepBall with classification layer

# %% [markdown]
# # General setup

# %% [markdown]
# Mounting the drive

# %%
from google.colab import drive, files
drive.mount('/content/drive/')
folderpath = '/content/drive/My Drive/DL_TAU2019/Project_300746930_034915504/'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %% [markdown]
# Installing all the needed lib.

# %%
# !pip install torch numpy torchvision matplotlib tabulate
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, TensorDataset
from torchvision import transforms, utils, datasets
import matplotlib.pyplot as plt
import numpy as np
from tabulate import tabulate
import pickle

# %%
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# %% [markdown]
# #Dataset Loading

# %%
idx = 0
train_batch = pickle.load( open( folderpath + "Dataset/train/train_batch_file" + str(idx)+".h5", "rb" ) )
Images = train_batch[0]
Labels = train_batch[1][:,0]
while idx < 5:
  idx += 1
  train_batch = pickle.load( open( folderpath + "Dataset/train/train_batch_file"+str(idx)+".h5", "rb" ) )
  Images = torch.cat((Images,train_batch[0]))
  Labels = torch.cat((Labels,train_batch[1][:,0]))
  print(idx)
del train_batch

train_dataset = TensorDataset(Images,Labels)

del Images,Labels
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
batch_size = 50
train_dataloader = DataLoader(train_dataset,batch_size=batch_size,shuffle=True)
print(len(train_dataloader))
# Out:
# 240

# %%
idx = 0
train_batch = pickle.load( open( folderpath + "Dataset/test/test_batch_file" + str(idx)+".data", "rb" ) )
Images = train_batch[0]
Labels = train_batch[1][:,0]
while idx < 2:
  idx += 1
  train_batch = pickle.load( open( folderpath + "Dataset/test/test_batch_file"+str(idx)+".data", "rb" ) )
  Images = torch.cat((Images,train_batch[0]))
  Labels = torch.cat((Labels,train_batch[1][:,0]))
  print(idx)
  del train_batch
test_dataset = TensorDataset(Images,Labels)
del Images,Labels
# Out:
# 1
# 2

# %%
test_dataloader = DataLoader(test_dataset,batch_size=batch_size,shuffle=True)
print(len(test_dataloader))
# Out:
# 120

# %%
# uncomment this for cross-validation

# test_idx = int(len(Images)*0.2)
# val_x, test_x = Images[:test_idx], Images[test_idx:]
# val_y, test_y = Labels[:test_idx], Labels[test_idx:]


# valid_dataset = TensorDataset(val_x,val_y)
# valid_dataloader = DataLoader(valid_dataset,batch_size=batch_size,shuffle=True)
# print(len(valid_dataloader))
# test_dataset = TensorDataset(test_x,test_y)
# test_dataloader = DataLoader(test_dataset,batch_size=batch_size,shuffle=True)
# print(len(test_dataloader))
# del Images,Labels

# %% [markdown]
# # DeepBall

# %% [markdown]
# **Hyperparameters**

# %%
inital_lr = 0.001
SGDlr = 0.1
num_epochs = 75 #number of epochs 
toSGD = 1 # after num_epochs/toSGD switch to Adam 
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
if device != "cpu":
  print("GPU is available")
else:
  print("Work on CPU")
BN = True
DP = 0
WD = 0
clip = 0
# Out:
# GPU is available

# %% [markdown]
# *Network Classes and Training Functions*

# %%
class DeepBall(nn.Module):
    def __init__(self):
        super(DeepBall, self).__init__()
        # the 1st conv. block 
        self.conv11 = nn.Conv2d(3, 8, 3,stride=2,padding=1)
        self.conv12 = nn.Conv2d(8, 8, 3,stride=1,padding=1) 
        
         # pooling size 2
        self.pool = nn.MaxPool2d(2, 2) 

        # the 2nd conv. block 
        self.conv21 = nn.Conv2d(8, 16, 3,padding=1)
        self.conv22 = nn.Conv2d(16, 16, 3,padding=1)
        
        # the 3rd conv. block 
        self.conv31 = nn.Conv2d(16, 32, 3,padding=1)
        self.conv32 = nn.Conv2d(32, 32, 3,padding=1)
        
        # the 4th conv. block 
        self.conv41 = nn.Conv2d(56, 56, 3,padding=1)
        self.conv42 = nn.Conv2d(56, 2, 3,padding=1)
        
        # Upsampling
        self.ups24 = nn.Upsample(scale_factor=2)
        self.ups34 = nn.Upsample(scale_factor=4)
        
        self.bn11 = nn.BatchNorm2d(8)
        self.bn12 = nn.BatchNorm2d(8)
        self.bn21 = nn.BatchNorm2d(16)
        self.bn22 = nn.BatchNorm2d(16)
        self.bn31 = nn.BatchNorm2d(32)
        self.bn32 = nn.BatchNorm2d(32)
        self.bn41 = nn.BatchNorm2d(56)
        self.bn42 = nn.BatchNorm2d(2)
        
    def forward(self, x):
      # 1st block
      if x.size()[2]!=272 or x.size()[3]!=480:
        x = F.interpolate(x, size=(272,480))
      
      x1 = F.relu(self.bn11(self.conv11(x)))
      x1 = F.relu(self.bn12(self.conv12(x1)))
      x1 = self.pool(x1)
      
      # 2nd Block
      x2 = F.relu(self.bn21(self.conv21(x1)))
      x2 = F.relu(self.bn22(self.conv22(x2)))
      x2 = self.pool(x2)
      
      # 3rd Block
      x3 = F.relu(self.bn31(self.conv31(x2)))
      x3 = F.relu(self.bn32(self.conv32(x3)))
      x3 = self.pool(x3)

      # 4th Block
      x2 = self.ups24(x2)
      x3 = self.ups34(x3)
      x4 = torch.cat([x2,x3,x1],dim=1)
      x4 = F.relu(self.bn41(self.conv41(x4)))
      x4 = F.relu(self.bn42(self.conv42(x4)))  
      
      out = F.log_softmax(x4,dim=1)
      if out.size()[2]!=68 or out.size()[3]!=120:
        out = F.interpolate(out, size=(68,120))
      del x1,x2,x3,x4
      torch.cuda.empty_cache()
      return out

# %%
def DeepBallLoss(Pre,Tar,notlogflag = False):
  N_b = Tar.size()[0]
  Ballgt = Tar
  zer = torch.zeros_like(Ballgt)
  N = torch.sum(Ballgt,dim=(1,2)).int()+1
  BGgt = 1 - Tar

  M = torch.sum(BGgt,dim=(1,2)).int()+1
  if notlogflag:
    Pre = torch.log(Pre)
  Ballcm = Pre[:,0,:,:]
  BGcm = Pre[:,1,:,:]
  Lpos = torch.sum(torch.addcmul(zer.double(),1,Ballcm.double(),Ballgt.double()),dim=(1,2))

  Lpos = torch.sum(torch.addcdiv(torch.zeros_like(N).double(),1,Lpos.double(),N.double()))

  Lneg = torch.sum(torch.addcmul(zer.double(),1,BGcm.double(),BGgt.double()),dim=(1,2))
  
  Lneg = torch.sum(torch.addcdiv(torch.zeros_like(M).double(),1,Lneg.double(),M.double()))

  del Ballgt,BGgt,Ballcm,BGcm
  torch.cuda.empty_cache()

  return -Lpos-0.2*Lneg

# %%
# For debugg

# with torch.no_grad():
#   model = DeepBall()
#   model.eval()
#   x = torch.randn([16,3,272,480])
#   yt = torch.rand([16,68,120])
#   yt = yt.int()
#   print(x.size())
#   y =  model(x)
#   print(y.size())
#   loss = DeepBallLoss(y, yt)
#   print(loss)
# # del x, y, model,loss

# %% [markdown]
# Training function

# %%
def run_epochDeepBall(model, data,optimizer=False, is_train=False, clip=0):
  """Runs the model on the given data."""
  if is_train:
    model.train()
  else:
    model.eval()
  costs = 0.0
  iters = 0
  for iteration, (images, labels) in enumerate(data):
    images, labels = images.to(device), labels.to(device)
    model.zero_grad()
    output = model(images.float()/255.0)
    loss = DeepBallLoss(output, labels) 
    costs += loss.item()
    iters += 1
    if is_train:
      loss.backward()
      if clip>0:
        nn.utils.clip_grad_norm_(model.parameters(), clip)
      optimizer.step()
  del loss
  return (costs / iters)

# %% [markdown]
# ## ***Training DeepBall***

# %%
model = DeepBall().to(device)
# model.apply(weights_init)
model.to(device)
# optimizer = torch.optim.SGD(model.parameters(),lr = SGDlr,weight_decay=WD)
optimizer = torch.optim.Adam(model.parameters(),lr = inital_lr,weight_decay=WD)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.8)
ValidLoss = 10000000
flag = 0
cntr = 0
TrainP = []
ValidP = []
TestP = []
print("++++++++++++++++++++++++++ Training ++++++++++++++++++++++++++")
for epoch in range(num_epochs):
  if epoch == int(num_epochs/toSGD):
      print("++++++++++++++++++++++++++ Switching to Adam++++++++++++++++++++++++++")
      del optimizer
      optimizer = torch.optim.Adam(model.parameters(),lr = inital_lr)
  _ = run_epochDeepBall(model, train_dataloader,optimizer, True,clip)
  scheduler.step()
  with torch.no_grad():
    train_p = run_epochDeepBall(model, train_dataloader,optimizer, False) 
    # valid_p = run_epoch(model, valid_dataloader,optimizer) # uncomment for cross-validation
    test_p = run_epochDeepBall(model, test_dataloader,optimizer)
  valid_p = test_p # comment for cross-validation

  TrainP.append(train_p)
  ValidP.append(valid_p)
  TestP.append(test_p)
  if ValidLoss > valid_p:
    torch.save(model.state_dict(), folderpath+'models/DeepBallmodel.pt')
    TrainLoss = train_p
    ValidLoss = valid_p
    TestLoss = test_p
    cntr = 0
    if flag == 1:
      flag = 0
  elif flag == 0:
    flag = 1
    print('------------------ best model saved ---------------------------')
  else:
    cntr += 1
    if cntr == int(num_epochs):
      num_epochs = epoch + 1
      print('-------------- over-training !!! Stop Training --------------------')
      break
    
  print('>> epoch: {}, train_loss: {:.3f},  test_loss: {:.3f}'.format(epoch+1, train_p,test_p))           

# print('Test loss: {:.2f}'.format(TestPrepGRUdrop))
print("++++++++++++++++++++++++++ Done! ++++++++++++++++++++++++++")
plt.figure(figsize=(15,10))
plt.plot(range(1,num_epochs+1),TrainP, label = 'Train')
# plt.plot(range(1,num_epochs+1),ValidP, label = 'Validation') # uncomment for cross-validation
plt.plot(range(1,num_epochs+1),TestP, label = 'Test')
plt.xticks(np.arange(0, num_epochs+1, 2.0))
plt.ylabel('Loss')
plt.xlabel('epochs')
plt.legend()
# plt.title('Loss DeepBall')
plt.grid(True)
plt.show()
DeepBallmodel = model
del ValidLoss, cntr, TrainP, ValidP, TestP
del model,optimizer
# Out:
# ++++++++++++++++++++++++++ Training ++++++++++++++++++++++++++
# >> epoch: 1, train_loss: 4.945,  test_loss: 4.509
# >> epoch: 2, train_loss: 4.145,  test_loss: 3.866
# >> epoch: 3, train_loss: 3.431,  test_loss: 3.134
# >> epoch: 4, train_loss: 3.007,  test_loss: 3.053
# >> epoch: 5, train_loss: 2.580,  test_loss: 2.623
# >> epoch: 6, train_loss: 2.386,  test_loss: 2.314
# >> epoch: 7, train_loss: 2.092,  test_loss: 2.143
# >> epoch: 8, train_loss: 1.651,  test_loss: 1.713
# ------------------ best model saved ---------------------------
# >> epoch: 9, train_loss: 1.606,  test_loss: 1.754
# >> epoch: 10, train_loss: 1.591,  test_loss: 1.717
# >> epoch: 11, train_loss: 1.334,  test_loss: 1.385
# ------------------ best model saved ---------------------------
# >> epoch: 12, train_loss: 1.197,  test_loss: 1.444
# >> epoch: 13, train_loss: 1.180,  test_loss: 1.266
# ------------------ best model saved ---------------------------
# >> epoch: 14, train_loss: 1.075,  test_loss: 1.356
# >> epoch: 15, train_loss: 0.979,  test_loss: 1.418
# >> epoch: 16, train_loss: 0.940,  test_loss: 1.399
# >> epoch: 17, train_loss: 0.967,  test_loss: 1.254
# ------------------ best model saved ---------------------------
# >> epoch: 18, train_loss: 0.877,  test_loss: 1.276
# >> epoch: 19, train_loss: 0.824,  test_loss: 1.200
# ------------------ best model saved ---------------------------
# >> epoch: 20, train_loss: 0.771,  test_loss: 1.362
# >> epoch: 21, train_loss: 0.731,  test_loss: 1.210
# >> epoch: 22, train_loss: 0.877,  test_loss: 1.250
# >> epoch: 23, train_loss: 0.735,  test_loss: 1.063
# ------------------ best model saved ---------------------------
# >> epoch: 24, train_loss: 0.549,  test_loss: 1.268
# >> epoch: 25, train_loss: 0.588,  test_loss: 1.072
# >> epoch: 26, train_loss: 0.500,  test_loss: 1.232
# >> epoch: 27, train_loss: 0.486,  test_loss: 1.264
# >> epoch: 28, train_loss: 0.511,  test_loss: 1.187
# >> epoch: 29, train_loss: 0.436,  test_loss: 1.155
# >> epoch: 30, train_loss: 0.443,  test_loss: 1.155
# >> epoch: 31, train_loss: 0.646,  test_loss: 1.187
# >> epoch: 32, train_loss: 0.408,  test_loss: 1.024
# ------------------ best model saved ---------------------------
# >> epoch: 33, train_loss: 0.330,  test_loss: 1.318
# >> epoch: 34, train_loss: 0.287,  test_loss: 1.271
# >> epoch: 35, train_loss: 0.264,  test_loss: 1.081
# >> epoch: 36, train_loss: 0.265,  test_loss: 1.219
# >> epoch: 37, train_loss: 0.260,  test_loss: 1.282
# >> epoch: 38, train_loss: 0.209,  test_loss: 1.700
# >> epoch: 39, train_loss: 0.274,  test_loss: 1.379
# >> epoch: 40, train_loss: 0.333,  test_loss: 1.219
# >> epoch: 41, train_loss: 0.232,  test_loss: 1.488
# >> epoch: 42, train_loss: 0.198,  test_loss: 1.575
# >> epoch: 43, train_loss: 0.181,  test_loss: 1.643
# >> epoch: 44, train_loss: 0.172,  test_loss: 1.748
# >> epoch: 45, train_loss: 0.178,  test_loss: 1.869
# >> epoch: 46, train_loss: 0.219,  test_loss: 1.367
# >> epoch: 47, train_loss: 0.168,  test_loss: 1.796
# >> epoch: 48, train_loss: 0.201,  test_loss: 1.514
# >> epoch: 49, train_loss: 0.291,  test_loss: 1.372
# >> epoch: 50, train_loss: 0.204,  test_loss: 2.201
# >> epoch: 51, train_loss: 0.188,  test_loss: 1.645
# >> epoch: 52, train_loss: 0.276,  test_loss: 0.903
# ------------------ best model saved ---------------------------
# >> epoch: 53, train_loss: 0.175,  test_loss: 1.409
# >> epoch: 54, train_loss: 0.165,  test_loss: 1.434
# >> epoch: 55, train_loss: 0.149,  test_loss: 1.795
# >> epoch: 56, train_loss: 0.144,  test_loss: 1.972
# >> epoch: 57, train_loss: 0.140,  test_loss: 2.053
# >> epoch: 58, train_loss: 0.140,  test_loss: 2.006
# >> epoch: 59, train_loss: 0.161,  test_loss: 2.056
# >> epoch: 60, train_loss: 0.596,  test_loss: 0.990
# >> epoch: 61, train_loss: 0.210,  test_loss: 1.246
# >> epoch: 62, train_loss: 0.215,  test_loss: 0.791
# ------------------ best model saved ---------------------------
# >> epoch: 63, train_loss: 0.159,  test_loss: 1.532
# >> epoch: 64, train_loss: 0.148,  test_loss: 1.558
# >> epoch: 65, train_loss: 0.140,  test_loss: 1.778
# >> epoch: 66, train_loss: 0.137,  test_loss: 1.952
# >> epoch: 67, train_loss: 0.137,  test_loss: 1.886
# >> epoch: 68, train_loss: 0.132,  test_loss: 2.024
# >> epoch: 69, train_loss: 0.132,  test_loss: 2.003
# >> epoch: 70, train_loss: 0.129,  test_loss: 2.195
# >> epoch: 71, train_loss: 0.130,  test_loss: 2.330
# >> epoch: 72, train_loss: 0.127,  test_loss: 2.396
# >> epoch: 73, train_loss: 0.126,  test_loss: 2.509
# >> epoch: 74, train_loss: 0.126,  test_loss: 2.725
# >> epoch: 75, train_loss: 0.125,  test_loss: 2.499
# ++++++++++++++++++++++++++ Done! ++++++++++++++++++++++++++

# %% [markdown]
# Random check

# %%
DeepBallmodel = DeepBall().to(device)
DeepBallmodel.load_state_dict(torch.load(folderpath+'models/DeepBallmodel.pt')) #load the last checkpoint
with torch.no_grad():
  DeepBallmodel.eval()
  index = 10
  img, label =  test_dataset[500]

  img = (img.view(1,3,272,480)).to(device)
  Mask= DeepBallmodel(img.float()/255.0)
  Mask = torch.exp(Mask)
# print(label.size())
a = Mask[0][0].cpu().numpy()
pos = np.unravel_index(np.argmax(a, axis=None), a.shape)
real_pos = np.unravel_index(np.argmax(label.cpu().numpy(), axis=None), label.cpu().numpy().shape)
print(pos, real_pos, a.max())
plt.figure(figsize=(20,14))
plt.subplot(2,2,1)
img = img.to('cpu')
img = img.view(3,272,480)

plt.imshow(label.cpu(),cmap='gray')
plt.subplot(2,2,2)
om = 1-torch.argmax(Mask.squeeze(), dim=0).detach().cpu().numpy()
Mask = Mask.cpu()
plt.imshow(np.transpose(img.numpy(),(1,2,0)))
plt.subplot(2,2,3)
plt.imshow(Mask[0][0], cmap='gray')
plt.subplot(2,2,4)
plt.imshow(Mask[0][1], cmap='gray')
plt.show()
# Out:
# (11, 29) (11, 29) 0.9999837

# %% [markdown]
# # DeepBall with a classification layer

# %%
class DeepBallClass(nn.Module):
    def __init__(self, BN = True,DP = 0):
        super(DeepBallClass, self).__init__()
        self.BN = BN
        self.DP = DP
        # the 1st conv. block 
        self.conv11 = nn.Conv2d(3, 8, 3,stride=2,padding=1)
        
        self.conv12 = nn.Conv2d(8, 8, 3,stride=1,padding=1) 
        
         # pooling size 2
        self.pool = nn.MaxPool2d(2, 2) 

        # the 2nd conv. block 
        self.conv21 = nn.Conv2d(8, 16, 3,padding=1)
        
        self.conv22 = nn.Conv2d(16, 16, 3,padding=1)
        
        # the 3rd conv. block 
        self.conv31 = nn.Conv2d(16, 32, 3,padding=1)
        
        self.conv32 = nn.Conv2d(32, 32, 3,padding=1)
        
        # the 4th conv. block 
        self.conv41 = nn.Conv2d(56, 56, 3,padding=1)
        
        self.conv42 = nn.Conv2d(56, 2, 3,padding=1)
        
        # Upsampling
        self.ups24 = nn.Upsample(scale_factor=2)
        self.ups34 = nn.Upsample(scale_factor=4)
        if BN:
          self.bn11 = nn.BatchNorm2d(8)
          self.bn12 = nn.BatchNorm2d(8)
          self.bn21 = nn.BatchNorm2d(16)
          self.bn22 = nn.BatchNorm2d(16)
          self.bn31 = nn.BatchNorm2d(32)
          self.bn32 = nn.BatchNorm2d(32)
          self.bn41 = nn.BatchNorm2d(56)
          self.bn42 = nn.BatchNorm2d(2)
        if DP > 0:
          self.dropout2d = nn.Dropout2d(p=DP)
        
        self.fc1 = nn.Linear(32*30*17,200)
        self.fc2 = nn.Linear(200,1)
        # self.sm = nn.Sigmoid()

    def forward(self, x):
      # 1st block
      BN = self.BN
      DP = self.DP
      if x.size()[2]!=272 or x.size()[3]!=480:
        x = F.interpolate(x, size=(272,480))
      if BN:
        x1 = F.relu(self.bn11(self.conv11(x)))
        if DP > 0:
          x1 = self.dropout2d(x1)
        x1 = F.relu(self.bn12(self.conv12(x1)))
        if DP > 0:
          x1 = self.dropout2d(x1)
      else:
        x1 = F.relu(self.conv11(x))
        if DP > 0:
          x1 = self.dropout2d(x1)
        x1 = F.relu(self.conv12(x1))
        if DP > 0:
          x1 = self.dropout2d(x1)
      x1 = self.pool(x1)
      
      # 2nd Block
      if BN:
        x2 = F.relu(self.bn21(self.conv21(x1)))
        if DP > 0:
          x2 = self.dropout2d(x2)
        x2 = F.relu(self.bn22(self.conv22(x2)))
        if DP > 0:
          x2 = self.dropout2d(x2)
      else:
        x2 = F.relu(self.conv21(x1))
        if DP > 0:
          x2 = self.dropout2d(x2)
        x2 = F.relu(self.conv22(x2))
        if DP > 0:
          x2 = self.dropout2d(x2)
      
      # print(x2.size())
      x2 = self.pool(x2)
      
      # 3rd Block
      if BN:
        x3 = F.relu(self.bn31(self.conv31(x2)))
        if DP > 0:
          x3 = self.dropout2d(x3)
        x3 = F.relu(self.bn32(self.conv32(x3)))
        if DP > 0:
          x3 = self.dropout2d(x3)
      else:
        x3 = F.relu(self.conv31(x2))
        if DP > 0:
          x3 = self.dropout2d(x3)
        x3 = F.relu(self.conv32(x3))
        if DP > 0:
          x3 = self.dropout2d(x3)
      # print(x3.size())
      x3 = self.pool(x3)
      # print(x3.size())
      # 4th Block
      x2 = self.ups24(x2)
      x3u = self.ups34(x3)

      x4 = torch.cat([x2,x3u,x1],dim=1)
      if BN:
        x4 = F.relu(self.bn41(self.conv41(x4)))
        if DP > 0:
          x4 = self.dropout2d(x4)
        x4 = F.relu(self.bn42(self.conv42(x4)))
        if DP > 0:
          x4 = self.dropout2d(x4)
      else:
        x4 = F.relu(self.conv41(x4))
        if DP > 0:
          x4 = self.dropout2d(x4)
        x4 = F.relu(self.conv42(x4))
        if DP > 0:
          x4 = self.dropout2d(x4)
        
      out = F.log_softmax(x4,dim=1)
      x3 = x3.view(-1,32*30*17)
      x3 = self.fc2(F.relu(self.fc1(x3)))
      Cout = torch.sigmoid(x3)
      if out.size()[2]!=68 or out.size()[3]!=120:
        out = F.interpolate(out, size=(68,120))

      del x1,x2,x3,x4
      torch.cuda.empty_cache()
      return out,Cout

# %%
def DeepBallCalssLoss(Cout,Pre,Tar,notlogflag = False):
  N_b = Tar.size()[0]
  Ballgt = Tar
  N = torch.sum(Ballgt,dim=(1,2)).int()+1
  BGgt = 1 - Tar
  Targets = torch.sum(Ballgt,dim=(1,2)).float()
  
  Lclass = F.binary_cross_entropy(Cout.view(N_b),Targets)

  M = torch.sum(BGgt,dim=(1,2)).int()+1
  if notlogflag:
    Pre = torch.log(Pre)
  Ballcm = Pre[:,0,:,:]
  BGcm = Pre[:,1,:,:]
  Lpos = torch.sum(torch.mul(Ballcm.double(),Ballgt.double()),dim=(1,2))
  # print(Lpos.size())
  Lpos = torch.sum(torch.div(Lpos.double(),N.double()))
  # print(Lpos)
  Lneg = torch.sum(torch.mul(BGcm.double(),BGgt.double()),dim=(1,2))
  
  Lneg = torch.sum(torch.div(Lneg.double(),M.double()))
  # print(Lneg.size())
  del Ballgt,BGgt,Ballcm,BGcm
  torch.cuda.empty_cache()
  # print(Lpos.item(),Lneg.item())
  return 0.8*(-Lpos-Lneg)+0.2*Lclass

# %% [markdown]
# ## Training proc. with class

# %%
def run_epochDeepBallclass(model, data,optimizer=False, is_train=False, clip=0):
  """Runs the model on the given data."""
  if is_train:
    model.train()
  else:
    model.eval()
  costs = 0.0
  iters = 0
  for iteration, (images, labels) in enumerate(data):
    images, labels = images.to(device), labels.to(device)
    model.zero_grad()
    output, c = model(images.float()/255.0)
    loss = DeepBallCalssLoss(c,output, labels) 
    costs += loss.item()
    iters += 1
    if is_train:
      loss.backward()
      if clip>0:
        nn.utils.clip_grad_norm_(model.parameters(), clip)
      optimizer.step()
  del loss
  return (costs / iters)

# %% [markdown]
# Main Training with class

# %%
model = DeepBallClass(DP = 0.2).to(device)
model.to(device)
# optimizer = torch.optim.SGD(model.parameters(),lr = SGDlr,weight_decay=WD)
optimizer = torch.optim.Adam(model.parameters(),lr = inital_lr,weight_decay=WD)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.5)
ValidLoss = 10000000
flag = 0
cntr = 0
TrainP = []
ValidP = []
TestP = []
print("++++++++++++++++++++++++++ Training ++++++++++++++++++++++++++")
for epoch in range(num_epochs):
  if epoch == int(num_epochs/toSGD):
      print("++++++++++++++++++++++++++ Switching to Adam++++++++++++++++++++++++++")
      del optimizer
      optimizer = torch.optim.Adam(model.parameters(),lr = inital_lr)
  _ = run_epochDeepBallclass(model, train_dataloader,optimizer, True,clip)
  scheduler.step()
  with torch.no_grad():
    train_p = run_epochDeepBallclass(model, train_dataloader,optimizer, False) # presents without the dropout
    # valid_p = run_epoch(model, valid_dataloader,optimizer) # uncomment for cross-validation
    test_p = run_epochDeepBallclass(model, test_dataloader,optimizer)
  valid_p = test_p # comment for cross-validation
  TrainP.append(train_p)
  ValidP.append(valid_p)
  TestP.append(test_p)
  if ValidLoss > valid_p:
    torch.save(model.state_dict(), folderpath+'models/DeepBallclassmodel.pt')
    TrainLoss = train_p
    ValidLoss = valid_p
    TestLoss = test_p
    cntr = 0
    if flag == 1:
      flag = 0
  elif flag == 0:
    flag = 1
    print('------------------ best model saved ---------------------------')
  else:
    cntr += 1
    if cntr == int(num_epochs):
      num_epochs = epoch + 1
      print('-------------- over-training !!! Stop Training --------------------')
      break
    
  print('>> epoch: {}, train_loss: {:.3f},  test_loss: {:.3f}'.format(epoch+1, train_p,test_p))           


print("++++++++++++++++++++++++++ Done! ++++++++++++++++++++++++++")
plt.figure(figsize=(15,10))
plt.plot(range(1,num_epochs+1),TrainP, label = 'Train')
# plt.plot(range(1,num_epochs+1),ValidP, label = 'Validation') # uncomment for cross-validation
plt.plot(range(1,num_epochs+1),TestP, label = 'Test')
plt.xticks(np.arange(0, num_epochs+1, 2.0))
plt.ylabel('Loss')
plt.xlabel('epochs')
plt.legend()
plt.title('Loss DeepBall')
plt.grid(True)
plt.show()
DeepBallClassmodel = model
del ValidLoss, cntr, TrainP, ValidP, TestP
del model,optimizer
# Out:
# ++++++++++++++++++++++++++ Training ++++++++++++++++++++++++++
# >> epoch: 1, train_loss: 18.205,  test_loss: 16.589
# >> epoch: 2, train_loss: 15.421,  test_loss: 14.407
# >> epoch: 3, train_loss: 13.451,  test_loss: 12.720
# >> epoch: 4, train_loss: 12.086,  test_loss: 11.491
# >> epoch: 5, train_loss: 10.489,  test_loss: 9.974
# >> epoch: 6, train_loss: 9.151,  test_loss: 8.736
# >> epoch: 7, train_loss: 8.176,  test_loss: 7.642
# >> epoch: 8, train_loss: 7.522,  test_loss: 7.153
# >> epoch: 9, train_loss: 6.531,  test_loss: 6.507
# >> epoch: 10, train_loss: 6.012,  test_loss: 6.032
# >> epoch: 11, train_loss: 5.730,  test_loss: 5.835
# >> epoch: 12, train_loss: 4.626,  test_loss: 4.973
# ------------------ best model saved ---------------------------
# >> epoch: 13, train_loss: 4.479,  test_loss: 5.073
# >> epoch: 14, train_loss: 4.071,  test_loss: 4.541
# >> epoch: 15, train_loss: 3.662,  test_loss: 3.871
# ------------------ best model saved ---------------------------
# >> epoch: 16, train_loss: 3.504,  test_loss: 3.933
# >> epoch: 17, train_loss: 3.322,  test_loss: 4.052
# >> epoch: 18, train_loss: 3.281,  test_loss: 3.796
# >> epoch: 19, train_loss: 2.862,  test_loss: 3.521
# >> epoch: 20, train_loss: 2.697,  test_loss: 3.301
# ------------------ best model saved ---------------------------
# >> epoch: 21, train_loss: 2.562,  test_loss: 3.305
# >> epoch: 22, train_loss: 2.463,  test_loss: 3.252
# >> epoch: 23, train_loss: 2.383,  test_loss: 3.014
# >> epoch: 24, train_loss: 2.305,  test_loss: 2.887
# ------------------ best model saved ---------------------------
# >> epoch: 25, train_loss: 2.181,  test_loss: 2.891
# >> epoch: 26, train_loss: 2.077,  test_loss: 2.820
# >> epoch: 27, train_loss: 2.055,  test_loss: 2.754
# >> epoch: 28, train_loss: 1.956,  test_loss: 2.712
# >> epoch: 29, train_loss: 1.891,  test_loss: 2.533
# >> epoch: 30, train_loss: 1.866,  test_loss: 2.511
# >> epoch: 31, train_loss: 1.822,  test_loss: 2.374
# ------------------ best model saved ---------------------------
# >> epoch: 32, train_loss: 1.812,  test_loss: 2.514
# >> epoch: 33, train_loss: 1.712,  test_loss: 2.389
# >> epoch: 34, train_loss: 1.670,  test_loss: 2.387
# >> epoch: 35, train_loss: 1.675,  test_loss: 2.223
# >> epoch: 36, train_loss: 1.574,  test_loss: 2.173
# >> epoch: 37, train_loss: 1.515,  test_loss: 2.073
# ------------------ best model saved ---------------------------
# >> epoch: 38, train_loss: 1.491,  test_loss: 2.181
# >> epoch: 39, train_loss: 1.470,  test_loss: 2.347
# >> epoch: 40, train_loss: 1.431,  test_loss: 2.238
# >> epoch: 41, train_loss: 1.378,  test_loss: 2.348
# >> epoch: 42, train_loss: 1.328,  test_loss: 2.170
# >> epoch: 43, train_loss: 1.292,  test_loss: 2.060
# >> epoch: 44, train_loss: 1.289,  test_loss: 2.031
# ------------------ best model saved ---------------------------
# >> epoch: 45, train_loss: 1.260,  test_loss: 2.075
# >> epoch: 46, train_loss: 1.265,  test_loss: 2.011
# ------------------ best model saved ---------------------------
# >> epoch: 47, train_loss: 1.233,  test_loss: 2.033
# >> epoch: 48, train_loss: 1.235,  test_loss: 1.958
# ------------------ best model saved ---------------------------
# >> epoch: 49, train_loss: 1.202,  test_loss: 2.037
# >> epoch: 50, train_loss: 1.180,  test_loss: 1.946
# ------------------ best model saved ---------------------------
# >> epoch: 51, train_loss: 1.164,  test_loss: 2.050
# >> epoch: 52, train_loss: 1.151,  test_loss: 1.944
# >> epoch: 53, train_loss: 1.120,  test_loss: 1.915
# >> epoch: 54, train_loss: 1.107,  test_loss: 1.844
# ------------------ best model saved ---------------------------
# >> epoch: 55, train_loss: 1.101,  test_loss: 1.873
# >> epoch: 56, train_loss: 1.106,  test_loss: 1.900
# >> epoch: 57, train_loss: 1.079,  test_loss: 1.923
# >> epoch: 58, train_loss: 1.083,  test_loss: 2.012
# >> epoch: 59, train_loss: 1.036,  test_loss: 1.772
# ------------------ best model saved ---------------------------
# >> epoch: 60, train_loss: 1.022,  test_loss: 1.824
# >> epoch: 61, train_loss: 1.013,  test_loss: 1.845
# >> epoch: 62, train_loss: 1.008,  test_loss: 1.807
# >> epoch: 63, train_loss: 1.014,  test_loss: 1.870
# >> epoch: 64, train_loss: 1.005,  test_loss: 1.918
# >> epoch: 65, train_loss: 1.015,  test_loss: 1.820
# >> epoch: 66, train_loss: 0.984,  test_loss: 1.897
# >> epoch: 67, train_loss: 0.973,  test_loss: 1.882
# >> epoch: 68, train_loss: 0.964,  test_loss: 1.808
# >> epoch: 69, train_loss: 0.984,  test_loss: 1.857
# >> epoch: 70, train_loss: 0.961,  test_loss: 1.875
# >> epoch: 71, train_loss: 0.974,  test_loss: 1.852
# >> epoch: 72, train_loss: 0.968,  test_loss: 1.927
# >> epoch: 73, train_loss: 0.934,  test_loss: 1.847
# >> epoch: 74, train_loss: 0.949,  test_loss: 1.895
# >> epoch: 75, train_loss: 0.923,  test_loss: 1.810
# ++++++++++++++++++++++++++ Done! ++++++++++++++++++++++++++

# %%
# DeepBallClassmodel = DeepBallClass(DP = 0.2).to(device)
DeepBallClassmodel.load_state_dict(torch.load(folderpath+'models/DeepBallclassmodel.pt')) #load the last checkpoint
with torch.no_grad():
  DeepBallClassmodel.eval()
  index = 540
  img, label =  test_dataset[500]
  img = (img.view(1,3,272,480)).to(device)
  Mask, Cout= DeepBallClassmodel(img.float()/255.0)
  Mask = torch.exp(Mask)

print(Cout.item())
a = Mask[0][0].cpu().numpy()
pos = np.unravel_index(np.argmax(a, axis=None), a.shape)
real_pos = np.unravel_index(np.argmax(label.cpu().numpy(), axis=None), label.cpu().numpy().shape)
print(pos, real_pos, a.max())
plt.figure(figsize=(20,15))
plt.subplot(2,2,1)
img = img.to('cpu')
img = img.view(3,272,480)
plt.imshow(label.cpu(),cmap='gray')
plt.subplot(2,2,2)
om = 1-torch.argmax(Mask.squeeze(), dim=0).detach().cpu().numpy()
Mask = Mask.cpu()
plt.imshow(np.transpose(img.numpy(),(1,2,0)))
plt.subplot(2,2,3)
plt.imshow(Mask[0][0], cmap='gray')
plt.subplot(2,2,4)
plt.imshow(Mask[0][1], cmap='gray')
plt.show()
# Out:
# 0.9607465863227844
# (11, 29) (11, 29) 0.9997502
